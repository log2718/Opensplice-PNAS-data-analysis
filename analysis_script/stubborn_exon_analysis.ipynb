# %%
from pathlib import Path 
import sys 
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

# %%
REPO_ROOT = Path("..").resolve()
sys.path.append(str(REPO_ROOT / "PNAS_model"))

from PNAS_model.model import PNASModel
