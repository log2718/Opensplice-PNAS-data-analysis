# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../media-14.tsv", sep="\t")

# %%
df.shape
# Out:
# (590104, 26)

# %%
print(df['mut'].value_counts())
print()
print(df['mut_type'].value_counts())
# Out:
# mut
# C        80167
# G        79592
# A        74798
# ∆3nt     72638
# ∆1nt     71810
# U        71786
# ∆6nt     71340
# ∆21nt    67973
# Name: count, dtype: int64
#
# mut_type
# sub      306343
# ∆3nt      72638
# ∆1nt      71810
# ∆6nt      71340
# ∆21nt     67973
# Name: count, dtype: int64
